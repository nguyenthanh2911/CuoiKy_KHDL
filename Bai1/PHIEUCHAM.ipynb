# %%
import pandas as pd
data =  pd.read_csv('DuLieu_Bai1.csv')
print(data)
# Out:
#      STT                                            Câu Hỏi  \
# 0      1  Which country has won the most Olympic swimmin...
# 1      2  Name three countries with the most swimmers pa...
# 2      3  Compare the Olympic swimming performances of t...
# 3      4  Which country has won the most Olympic gold me...
# 4      5  Which country has the most Paralympic swimming...
# ..   ...                                                ...
# 550  551  How is the Elo rating calculated after each game?
# 551  552  What are the challenges of the Elo rating syst...
# 552  553  How do online chess platforms adapt the Elo sy...
# 553  554  Can a player's Elo rating plateau, and how can...
# 554  555  How does the Elo system compare to other ratin...
#
#                                           Dịch Câu Hỏi  \
# 0    Nước nào có nhiều huy chương bơi lội Olympic n...
# 1    Kể tên 3 quốc gia có số lượng vận động viên bơ...
# 2    So sánh thành tích bơi lội Olympic của Hoa Kỳ ...
# ...

# %%
# Create an assessment sheet format
assessment_columns = ['STT', 'Câu Hỏi', 'Dịch Câu Hỏi', 'Trả Lời', 'Dịch Câu Trả lời', 
                      'Đánh giá độ chính xác', 'Đánh giá đầy đủ và chi tiết', 'Đánh giá dịch']

# Fill the new columns with placeholder text for assessments
assessment_data = data.assign(
    **{'Đánh giá độ chính xác': 'Cần đánh giá', 
       'Đánh giá đầy đủ và chi tiết': 'Cần đánh giá',
       'Đánh giá dịch': 'Cần đánh giá'}
)

# Show the first few rows of the assessment data
assessment_data[assessment_columns]
# Out:
#      STT                                            Câu Hỏi  \
# 0      1  Which country has won the most Olympic swimmin...
# 1      2  Name three countries with the most swimmers pa...
# 2      3  Compare the Olympic swimming performances of t...
# 3      4  Which country has won the most Olympic gold me...
# 4      5  Which country has the most Paralympic swimming...
# ..   ...                                                ...
# 550  551  How is the Elo rating calculated after each game?
# 551  552  What are the challenges of the Elo rating syst...
# 552  553  How do online chess platforms adapt the Elo sy...
# 553  554  Can a player's Elo rating plateau, and how can...
# 554  555  How does the Elo system compare to other ratin...
#
#                                           Dịch Câu Hỏi  \
# 0    Nước nào có nhiều huy chương bơi lội Olympic n...
# 1    Kể tên 3 quốc gia có số lượng vận động viên bơ...
# 2    So sánh thành tích bơi lội Olympic của Hoa Kỳ ...
# ...
